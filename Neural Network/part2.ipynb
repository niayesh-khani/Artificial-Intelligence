# %%
import cv2
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
# Load the image
image = cv2.imread('red_image.png')

# %%
# Convert image to HSV color space
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# %%
# Define lower and upper thresholds for red color in HSV
lower_red1 = np.array([0, 50, 50])
upper_red1 = np.array([10, 255, 255])
lower_red2 = np.array([170, 50, 50])
upper_red2 = np.array([180, 255, 255])

# Create masks for red pixels using the thresholds
red_mask1 = cv2.inRange(hsv_image, lower_red1, upper_red1)
red_mask2 = cv2.inRange(hsv_image, lower_red2, upper_red2)
red_mask = cv2.bitwise_or(red_mask1, red_mask2)

# Apply Canny edge detection on the red mask
edges = cv2.Canny(red_mask, 50, 150, apertureSize=3)

# Find contours in the edge image
contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
# Check if contours were found
if contours:
    # Extract the largest contour (assuming it corresponds to the red line)
    largest_contour = max(contours, key=cv2.contourArea)

    # Extract the coordinates of the red line
    x_coords = largest_contour[:, 0, 0]
    y_coords = largest_contour[:, 0, 1]

    # Print the coordinates of the red dots
    for x, y in zip(x_coords, y_coords):
        print(f"Red dot coordinates: ({x}, {y})")

    # Fit a polynomial curve to the coordinates
    degree = 3  # Degree of the polynomial curve
    coeffs = np.polyfit(x_coords, y_coords, degree)
    poly_func = np.poly1d(coeffs)

    # Generate x values for plotting the curve
    x_plot = np.linspace(min(x_coords), max(x_coords), 100)

    # Evaluate the polynomial function for the plotted x values
    y_plot = poly_func(x_plot)

    # Plot the original image with the detected red line and the fitted curve
    plt.figure(figsize=(8, 6))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.plot(x_coords, y_coords, 'ro', label='Detected Red Line')
    plt.plot(x_plot, y_plot, 'b-', label='Fitted Curve')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Fitting a Curve to the Detected Red Line')
    plt.legend()
    plt.show()
else:
    print("No red line detected.")
# Out:
# Red dot coordinates: (731, 7)
# Red dot coordinates: (730, 8)
# Red dot coordinates: (728, 8)
# Red dot coordinates: (727, 9)
# Red dot coordinates: (726, 9)
# Red dot coordinates: (725, 10)
# Red dot coordinates: (724, 10)
# Red dot coordinates: (721, 13)
# Red dot coordinates: (720, 13)
# Red dot coordinates: (719, 14)
# Red dot coordinates: (718, 14)
# Red dot coordinates: (717, 15)
# Red dot coordinates: (716, 15)
# Red dot coordinates: (715, 16)
# Red dot coordinates: (714, 16)
# Red dot coordinates: (713, 17)
# Red dot coordinates: (712, 17)
# Red dot coordinates: (711, 18)
# Red dot coordinates: (710, 18)
# Red dot coordinates: (709, 19)
# Red dot coordinates: (707, 19)
# Red dot coordinates: (706, 20)
# Red dot coordinates: (705, 20)
# Red dot coordinates: (704, 21)
# Red dot coordinates: (703, 21)
# Red dot coordinates: (702, 22)
# Red dot coordinates: (701, 22)
# Red dot coordinates: (700, 23)
# Red dot coordinates: (699, 23)
# Red dot coordinates: (698, 24)
# Red dot coordinates: (697, 24)
# Red dot coordinates: (695, 26)
# Red dot coordinates: (693, 26)
# Red dot coordinates: (692, 27)
# Red dot coordinates: (691, 27)
# Red dot coordinates: (690, 28)
# Red dot coordinates: (689, 28)
# Red dot coordinates: (685, 32)
# Red dot coordinates: (684, 32)
# Red dot coordinates: (682, 34)
# Red dot coordinates: (673, 34)
# Red dot coordinates: (672, 35)
# Red dot coordinates: (671, 35)
# Red dot coordinates: (669, 37)
# Red dot coordinates: (669, 38)
# Red dot coordinates: (667, 40)
# Red dot coordinates: (667, 41)
# Red dot coordinates: (666, 42)
# Red dot coordinates: (666, 44)
# Red dot coordinates: (665, 45)
# Red dot coordinates: (665, 48)
# Red dot coordinates: (666, 49)
# Red dot coordinates: (666, 51)
# Red dot coordinates: (667, 52)
# Red dot coordinates: (667, 53)
# Red dot coordinates: (668, 54)
# Red dot coordinates: (668, 56)
# Red dot coordinates: (669, 57)
# Red dot coordinates: (669, 63)
# Red dot coordinates: (670, 64)
# Red dot coordinates: (670, 66)
# Red dot coordinates: (671, 67)
# Red dot coordinates: (671, 74)
# Red dot coordinates: (672, 75)
# Red dot coordinates: (672, 81)
# Red dot coordinates: (673, 82)
# Red dot coordinates: (673, 86)
# Red dot coordinates: (674, 87)
# Red dot coordinates: (674, 97)
# Red dot coordinates: (673, 98)
# Red dot coordinates: (673, 99)
# Red dot coordinates: (668, 104)
# Red dot coordinates: (667, 104)
# Red dot coordinates: (662, 109)
# Red dot coordinates: (649, 109)
# Red dot coordinates: (648, 110)
# Red dot coordinates: (642, 110)
# Red dot coordinates: (641, 111)
# Red dot coordinates: (638, 111)
# Red dot coordinates: (637, 112)
# Red dot coordinates: (636, 112)
# Red dot coordinates: (635, 113)
# Red dot coordinates: (634, 113)
# Red dot coordinates: (632, 115)
# Red dot coordinates: (632, 116)
# Red dot coordinates: (631, 117)
# Red dot coordinates: (631, 119)
# Red dot coordinates: (632, 120)
# Red dot coordinates: (632, 123)
# Red dot coordinates: (633, 124)
# Red dot coordinates: (633, 129)
# Red dot coordinates: (632, 130)
# Red dot coordinates: (627, 130)
# Red dot coordinates: (626, 129)
# Red dot coordinates: (625, 129)
# Red dot coordinates: (624, 128)
# Red dot coordinates: (623, 129)
# Red dot coordinates: (621, 129)
# Red dot coordinates: (620, 128)
# Red dot coordinates: (617, 128)
# Red dot coordinates: (616, 129)
# Red dot coordinates: (611, 129)
# Red dot coordinates: (610, 128)
# Red dot coordinates: (607, 128)
# Red dot coordinates: (605, 126)
# Red dot coordinates: (605, 113)
# Red dot coordinates: (604, 112)
# Red dot coordinates: (604, 101)
# Red dot coordinates: (603, 100)
# Red dot coordinates: (603, 80)
# Red dot coordinates: (601, 78)
# Red dot coordinates: (601, 77)
# Red dot coordinates: (600, 76)
# Red dot coordinates: (600, 75)
# Red dot coordinates: (599, 74)
# Red dot coordinates: (598, 74)
# Red dot coordinates: (597, 73)
# Red dot coordinates: (596, 73)
# Red dot coordinates: (595, 72)
# Red dot coordinates: (594, 72)
# Red dot coordinates: (593, 71)
# Red dot coordinates: (592, 71)
# Red dot coordinates: (591, 70)
# Red dot coordinates: (590, 70)
# Red dot coordinates: (589, 69)
# Red dot coordinates: (587, 69)
# Red dot coordinates: (585, 67)
# Red dot coordinates: (584, 67)
# Red dot coordinates: (583, 66)
# Red dot coordinates: (572, 66)
# Red dot coordinates: (571, 67)
# Red dot coordinates: (569, 67)
# Red dot coordinates: (568, 68)
# Red dot coordinates: (566, 68)
# Red dot coordinates: (565, 69)
# Red dot coordinates: (563, 69)
# Red dot coordinates: (562, 70)
# Red dot coordinates: (560, 70)
# Red dot coordinates: (559, 71)
# Red dot coordinates: (556, 71)
# Red dot coordinates: (555, 72)
# Red dot coordinates: (553, 72)
# Red dot coordinates: (552, 73)
# Red dot coordinates: (548, 73)
# Red dot coordinates: (547, 74)
# Red dot coordinates: (543, 74)
# Red dot coordinates: (542, 75)
# Red dot coordinates: (536, 75)
# Red dot coordinates: (535, 76)
# Red dot coordinates: (524, 76)
# Red dot coordinates: (523, 77)
# Red dot coordinates: (512, 77)
# Red dot coordinates: (511, 78)
# Red dot coordinates: (500, 78)
# Red dot coordinates: (499, 79)
# Red dot coordinates: (496, 79)
# Red dot coordinates: (495, 80)
# Red dot coordinates: (492, 80)
# Red dot coordinates: (491, 81)
# Red dot coordinates: (489, 81)
# Red dot coordinates: (488, 82)
# Red dot coordinates: (486, 82)
# Red dot coordinates: (485, 83)
# Red dot coordinates: (483, 83)
# Red dot coordinates: (482, 84)
# Red dot coordinates: (481, 84)
# Red dot coordinates: (480, 85)
# Red dot coordinates: (479, 85)
# Red dot coordinates: (478, 86)
# Red dot coordinates: (475, 86)
# Red dot coordinates: (474, 87)
# Red dot coordinates: (473, 87)
# Red dot coordinates: (472, 88)
# Red dot coordinates: (471, 88)
# Red dot coordinates: (468, 91)
# Red dot coordinates: (467, 91)
# Red dot coordinates: (466, 92)
# Red dot coordinates: (464, 92)
# Red dot coordinates: (463, 93)
# Red dot coordinates: (462, 93)
# Red dot coordinates: (461, 94)
# Red dot coordinates: (458, 94)
# Red dot coordinates: (457, 95)
# Red dot coordinates: (456, 95)
# Red dot coordinates: (455, 96)
# Red dot coordinates: (453, 96)
# Red dot coordinates: (452, 95)
# Red dot coordinates: (452, 94)
# Red dot coordinates: (451, 93)
# Red dot coordinates: (451, 83)
# Red dot coordinates: (450, 82)
# Red dot coordinates: (450, 77)
# Red dot coordinates: (449, 76)
# Red dot coordinates: (449, 73)
# Red dot coordinates: (448, 72)
# Red dot coordinates: (448, 63)
# Red dot coordinates: (447, 62)
# Red dot coordinates: (447, 56)
# Red dot coordinates: (446, 55)
# Red dot coordinates: (446, 52)
# Red dot coordinates: (444, 50)
# Red dot coordinates: (444, 46)
# Red dot coordinates: (443, 45)
# Red dot coordinates: (442, 45)
# Red dot coordinates: (440, 43)
# Red dot coordinates: (439, 43)
# Red dot coordinates: (438, 42)
# Red dot coordinates: (437, 42)
# Red dot coordinates: (436, 41)
# Red dot coordinates: (435, 41)
# Red dot coordinates: (434, 40)
# Red dot coordinates: (433, 40)
# Red dot coordinates: (432, 39)
# Red dot coordinates: (429, 39)
# Red dot coordinates: (428, 38)
# Red dot coordinates: (427, 38)
# Red dot coordinates: (426, 37)
# Red dot coordinates: (425, 37)
# Red dot coordinates: (424, 36)
# Red dot coordinates: (423, 36)
# Red dot coordinates: (422, 35)
# Red dot coordinates: (421, 35)
# Red dot coordinates: (420, 34)
# Red dot coordinates: (419, 34)
# Red dot coordinates: (418, 33)
# Red dot coordinates: (417, 33)
# Red dot coordinates: (416, 32)
# Red dot coordinates: (415, 32)
# Red dot coordinates: (414, 31)
# Red dot coordinates: (413, 31)
# Red dot coordinates: (412, 30)
# Red dot coordinates: (411, 30)
# Red dot coordinates: (410, 29)
# Red dot coordinates: (408, 29)
# Red dot coordinates: (407, 28)
# Red dot coordinates: (402, 28)
# Red dot coordinates: (401, 27)
# Red dot coordinates: (389, 27)
# Red dot coordinates: (388, 28)
# Red dot coordinates: (364, 28)
# Red dot coordinates: (363, 29)
# Red dot coordinates: (346, 29)
# Red dot coordinates: (345, 30)
# Red dot coordinates: (341, 30)
# Red dot coordinates: (340, 31)
# Red dot coordinates: (335, 31)
# Red dot coordinates: (334, 32)
# Red dot coordinates: (329, 32)
# Red dot coordinates: (328, 33)
# Red dot coordinates: (323, 33)
# Red dot coordinates: (322, 34)
# Red dot coordinates: (319, 34)
# Red dot coordinates: (318, 35)
# Red dot coordinates: (316, 35)
# Red dot coordinates: (315, 36)
# Red dot coordinates: (312, 36)
# Red dot coordinates: (311, 37)
# Red dot coordinates: (310, 37)
# Red dot coordinates: (309, 38)
# Red dot coordinates: (308, 38)
# Red dot coordinates: (306, 40)
# Red dot coordinates: (305, 40)
# Red dot coordinates: (304, 41)
# Red dot coordinates: (304, 42)
# Red dot coordinates: (303, 43)
# Red dot coordinates: (303, 44)
# Red dot coordinates: (302, 45)
# Red dot coordinates: (302, 47)
# Red dot coordinates: (303, 48)
# Red dot coordinates: (303, 49)
# Red dot coordinates: (304, 50)
# Red dot coordinates: (304, 73)
# Red dot coordinates: (303, 74)
# Red dot coordinates: (303, 76)
# Red dot coordinates: (295, 84)
# Red dot coordinates: (294, 84)
# Red dot coordinates: (292, 86)
# Red dot coordinates: (284, 86)
# Red dot coordinates: (283, 85)
# Red dot coordinates: (280, 85)
# Red dot coordinates: (279, 84)
# Red dot coordinates: (276, 84)
# Red dot coordinates: (275, 83)
# Red dot coordinates: (269, 83)
# Red dot coordinates: (268, 82)
# Red dot coordinates: (258, 82)
# Red dot coordinates: (257, 81)
# Red dot coordinates: (254, 81)
# Red dot coordinates: (253, 80)
# Red dot coordinates: (248, 80)
# Red dot coordinates: (247, 79)
# Red dot coordinates: (241, 79)
# Red dot coordinates: (240, 78)
# Red dot coordinates: (236, 78)
# Red dot coordinates: (235, 77)
# Red dot coordinates: (228, 77)
# Red dot coordinates: (227, 76)
# Red dot coordinates: (221, 76)
# Red dot coordinates: (220, 75)
# Red dot coordinates: (215, 75)
# Red dot coordinates: (214, 74)
# Red dot coordinates: (205, 74)
# Red dot coordinates: (204, 73)
# Red dot coordinates: (197, 73)
# Red dot coordinates: (196, 72)
# Red dot coordinates: (189, 72)
# Red dot coordinates: (186, 69)
# Red dot coordinates: (186, 68)
# Red dot coordinates: (185, 67)
# Red dot coordinates: (185, 64)
# Red dot coordinates: (184, 63)
# Red dot coordinates: (184, 61)
# Red dot coordinates: (183, 60)
# Red dot coordinates: (183, 58)
# Red dot coordinates: (182, 57)
# Red dot coordinates: (182, 53)
# Red dot coordinates: (181, 52)
# Red dot coordinates: (181, 46)
# Red dot coordinates: (180, 45)
# Red dot coordinates: (180, 40)
# Red dot coordinates: (179, 39)
# Red dot coordinates: (179, 32)
# Red dot coordinates: (178, 31)
# Red dot coordinates: (178, 30)
# Red dot coordinates: (176, 28)
# Red dot coordinates: (175, 28)
# Red dot coordinates: (174, 27)
# Red dot coordinates: (172, 27)
# Red dot coordinates: (171, 26)
# Red dot coordinates: (168, 26)
# Red dot coordinates: (167, 25)
# Red dot coordinates: (166, 25)
# Red dot coordinates: (164, 23)
# Red dot coordinates: (163, 23)
# Red dot coordinates: (159, 19)
# Red dot coordinates: (158, 19)
# Red dot coordinates: (157, 18)
# Red dot coordinates: (154, 18)
# Red dot coordinates: (153, 19)
# Red dot coordinates: (152, 19)
# Red dot coordinates: (151, 20)
# Red dot coordinates: (150, 20)
# Red dot coordinates: (149, 21)
# Red dot coordinates: (148, 21)
# Red dot coordinates: (146, 23)
# Red dot coordinates: (145, 23)
# Red dot coordinates: (142, 26)
# Red dot coordinates: (141, 26)
# Red dot coordinates: (137, 30)
# Red dot coordinates: (136, 30)
# Red dot coordinates: (135, 31)
# Red dot coordinates: (134, 31)
# Red dot coordinates: (133, 32)
# Red dot coordinates: (132, 32)
# Red dot coordinates: (130, 34)
# Red dot coordinates: (129, 34)
# Red dot coordinates: (128, 35)
# Red dot coordinates: (127, 35)
# Red dot coordinates: (122, 40)
# Red dot coordinates: (121, 40)
# Red dot coordinates: (117, 44)
# Red dot coordinates: (117, 45)
# Red dot coordinates: (116, 46)
# Red dot coordinates: (116, 47)
# Red dot coordinates: (115, 48)
# Red dot coordinates: (115, 73)
# Red dot coordinates: (114, 74)
# Red dot coordinates: (114, 93)
# Red dot coordinates: (113, 94)
# Red dot coordinates: (113, 143)
# Red dot coordinates: (114, 144)
# Red dot coordinates: (114, 156)
# Red dot coordinates: (115, 157)
# Red dot coordinates: (115, 173)
# Red dot coordinates: (116, 174)
# Red dot coordinates: (116, 184)
# Red dot coordinates: (117, 185)
# Red dot coordinates: (117, 196)
# Red dot coordinates: (101, 212)
# Red dot coordinates: (100, 212)
# Red dot coordinates: (96, 216)
# Red dot coordinates: (95, 216)
# Red dot coordinates: (91, 220)
# Red dot coordinates: (90, 220)
# Red dot coordinates: (89, 221)
# Red dot coordinates: (88, 221)
# Red dot coordinates: (87, 222)
# Red dot coordinates: (86, 222)
# Red dot coordinates: (85, 223)
# Red dot coordinates: (83, 223)
# Red dot coordinates: (82, 224)
# Red dot coordinates: (80, 224)
# Red dot coordinates: (79, 225)
# Red dot coordinates: (78, 225)
# Red dot coordinates: (77, 226)
# Red dot coordinates: (76, 226)
# Red dot coordinates: (74, 228)
# Red dot coordinates: (74, 229)
# Red dot coordinates: (73, 230)
# Red dot coordinates: (73, 231)
# Red dot coordinates: (72, 232)
# Red dot coordinates: (72, 234)
# Red dot coordinates: (73, 235)
# Red dot coordinates: (73, 243)
# Red dot coordinates: (74, 244)
# Red dot coordinates: (74, 246)
# Red dot coordinates: (75, 247)
# Red dot coordinates: (75, 249)
# Red dot coordinates: (76, 250)
# Red dot coordinates: (76, 258)
# Red dot coordinates: (77, 259)
# Red dot coordinates: (77, 264)
# Red dot coordinates: (78, 265)
# Red dot coordinates: (78, 274)
# Red dot coordinates: (75, 277)
# Red dot coordinates: (74, 277)
# Red dot coordinates: (71, 280)
# Red dot coordinates: (70, 280)
# Red dot coordinates: (66, 284)
# Red dot coordinates: (66, 285)
# Red dot coordinates: (65, 286)
# Red dot coordinates: (65, 290)
# Red dot coordinates: (64, 291)
# Red dot coordinates: (65, 292)
# Red dot coordinates: (65, 293)
# Red dot coordinates: (70, 293)
# Red dot coordinates: (71, 292)
# Red dot coordinates: (72, 292)
# Red dot coordinates: (73, 291)
# Red dot coordinates: (74, 291)
# Red dot coordinates: (76, 289)
# Red dot coordinates: (76, 288)
# Red dot coordinates: (78, 286)
# Red dot coordinates: (79, 286)
# Red dot coordinates: (82, 283)
# Red dot coordinates: (83, 283)
# Red dot coordinates: (86, 280)
# Red dot coordinates: (86, 279)
# Red dot coordinates: (87, 278)
# Red dot coordinates: (87, 276)
# Red dot coordinates: (88, 275)
# Red dot coordinates: (88, 271)
# Red dot coordinates: (87, 270)
# Red dot coordinates: (87, 266)
# Red dot coordinates: (86, 265)
# Red dot coordinates: (86, 257)
# Red dot coordinates: (85, 256)
# Red dot coordinates: (85, 249)
# Red dot coordinates: (84, 248)
# Red dot coordinates: (84, 246)
# Red dot coordinates: (83, 245)
# Red dot coordinates: (83, 241)
# Red dot coordinates: (82, 240)
# Red dot coordinates: (82, 235)
# Red dot coordinates: (84, 233)
# Red dot coordinates: (85, 233)
# Red dot coordinates: (86, 232)
# Red dot coordinates: (88, 232)
# Red dot coordinates: (89, 231)
# Red dot coordinates: (91, 231)
# Red dot coordinates: (94, 228)
# Red dot coordinates: (96, 228)
# Red dot coordinates: (98, 226)
# Red dot coordinates: (99, 226)
# Red dot coordinates: (102, 223)
# Red dot coordinates: (103, 223)
# Red dot coordinates: (107, 219)
# Red dot coordinates: (108, 219)
# Red dot coordinates: (111, 216)
# Red dot coordinates: (112, 216)
# Red dot coordinates: (112, 215)
# Red dot coordinates: (115, 212)
# Red dot coordinates: (115, 211)
# Red dot coordinates: (117, 209)
# Red dot coordinates: (118, 209)
# Red dot coordinates: (123, 204)
# Red dot coordinates: (124, 204)
# Red dot coordinates: (124, 203)
# Red dot coordinates: (126, 201)
# Red dot coordinates: (126, 199)
# Red dot coordinates: (127, 198)
# Red dot coordinates: (127, 197)
# Red dot coordinates: (128, 196)
# Red dot coordinates: (128, 194)
# Red dot coordinates: (127, 193)
# Red dot coordinates: (127, 192)
# Red dot coordinates: (126, 191)
# Red dot coordinates: (126, 185)
# Red dot coordinates: (125, 184)
# Red dot coordinates: (125, 174)
# Red dot coordinates: (124, 173)
# Red dot coordinates: (124, 157)
# Red dot coordinates: (123, 156)
# Red dot coordinates: (123, 150)
# Red dot coordinates: (124, 149)
# Red dot coordinates: (124, 145)
# Red dot coordinates: (123, 144)
# Red dot coordinates: (123, 140)
# Red dot coordinates: (122, 139)
# Red dot coordinates: (122, 114)
# Red dot coordinates: (123, 113)
# Red dot coordinates: (123, 109)
# Red dot coordinates: (122, 108)
# Red dot coordinates: (122, 96)
# Red dot coordinates: (123, 95)
# Red dot coordinates: (123, 74)
# Red dot coordinates: (124, 73)
# Red dot coordinates: (124, 72)
# Red dot coordinates: (125, 71)
# Red dot coordinates: (125, 69)
# Red dot coordinates: (124, 68)
# Red dot coordinates: (124, 51)
# Red dot coordinates: (131, 44)
# Red dot coordinates: (132, 44)
# Red dot coordinates: (134, 42)
# Red dot coordinates: (135, 42)
# Red dot coordinates: (136, 41)
# Red dot coordinates: (137, 41)
# Red dot coordinates: (140, 38)
# Red dot coordinates: (142, 38)
# Red dot coordinates: (145, 35)
# Red dot coordinates: (146, 35)
# Red dot coordinates: (149, 32)
# Red dot coordinates: (150, 32)
# Red dot coordinates: (152, 30)
# Red dot coordinates: (153, 30)
# Red dot coordinates: (154, 29)
# Red dot coordinates: (155, 29)
# Red dot coordinates: (156, 30)
# Red dot coordinates: (157, 30)
# Red dot coordinates: (160, 33)
# Red dot coordinates: (161, 33)
# Red dot coordinates: (162, 34)
# Red dot coordinates: (164, 34)
# Red dot coordinates: (165, 35)
# Red dot coordinates: (168, 35)
# Red dot coordinates: (170, 37)
# Red dot coordinates: (170, 41)
# Red dot coordinates: (171, 42)
# Red dot coordinates: (171, 47)
# Red dot coordinates: (172, 48)
# Red dot coordinates: (172, 53)
# Red dot coordinates: (173, 54)
# Red dot coordinates: (173, 57)
# Red dot coordinates: (174, 58)
# Red dot coordinates: (174, 62)
# Red dot coordinates: (175, 63)
# Red dot coordinates: (175, 65)
# Red dot coordinates: (176, 66)
# Red dot coordinates: (176, 69)
# Red dot coordinates: (177, 70)
# Red dot coordinates: (177, 71)
# Red dot coordinates: (178, 72)
# Red dot coordinates: (178, 73)
# Red dot coordinates: (180, 75)
# Red dot coordinates: (180, 77)
# Red dot coordinates: (181, 78)
# Red dot coordinates: (181, 79)
# Red dot coordinates: (182, 80)
# Red dot coordinates: (182, 81)
# Red dot coordinates: (185, 81)
# Red dot coordinates: (186, 80)
# Red dot coordinates: (188, 80)
# Red dot coordinates: (189, 81)
# Red dot coordinates: (193, 81)
# Red dot coordinates: (194, 82)
# Red dot coordinates: (203, 82)
# Red dot coordinates: (204, 83)
# Red dot coordinates: (214, 83)
# Red dot coordinates: (215, 84)
# Red dot coordinates: (219, 84)
# Red dot coordinates: (220, 85)
# Red dot coordinates: (223, 85)
# Red dot coordinates: (224, 86)
# Red dot coordinates: (232, 86)
# Red dot coordinates: (233, 87)
# Red dot coordinates: (240, 87)
# Red dot coordinates: (241, 88)
# Red dot coordinates: (244, 88)
# Red dot coordinates: (245, 89)
# Red dot coordinates: (250, 89)
# Red dot coordinates: (251, 90)
# Red dot coordinates: (256, 90)
# Red dot coordinates: (257, 91)
# Red dot coordinates: (266, 91)
# Red dot coordinates: (267, 92)
# Red dot coordinates: (272, 92)
# Red dot coordinates: (273, 93)
# Red dot coordinates: (277, 93)
# Red dot coordinates: (278, 94)
# Red dot coordinates: (280, 94)
# Red dot coordinates: (281, 95)
# Red dot coordinates: (286, 95)
# Red dot coordinates: (287, 96)
# Red dot coordinates: (290, 96)
# Red dot coordinates: (291, 95)
# Red dot coordinates: (294, 95)
# Red dot coordinates: (295, 94)
# Red dot coordinates: (297, 94)
# Red dot coordinates: (298, 93)
# Red dot coordinates: (301, 93)
# Red dot coordinates: (305, 89)
# Red dot coordinates: (306, 89)
# Red dot coordinates: (306, 88)
# Red dot coordinates: (307, 87)
# Red dot coordinates: (307, 86)
# Red dot coordinates: (310, 83)
# Red dot coordinates: (311, 83)
# Red dot coordinates: (312, 82)
# Red dot coordinates: (312, 81)
# Red dot coordinates: (313, 80)
# Red dot coordinates: (313, 60)
# Red dot coordinates: (314, 59)
# Red dot coordinates: (314, 55)
# Red dot coordinates: (315, 54)
# Red dot coordinates: (315, 52)
# Red dot coordinates: (314, 51)
# Red dot coordinates: (314, 48)
# Red dot coordinates: (313, 47)
# Red dot coordinates: (315, 45)
# Red dot coordinates: (317, 45)
# Red dot coordinates: (318, 44)
# Red dot coordinates: (320, 44)
# Red dot coordinates: (321, 43)
# Red dot coordinates: (324, 43)
# Red dot coordinates: (325, 42)
# Red dot coordinates: (330, 42)
# Red dot coordinates: (331, 41)
# Red dot coordinates: (337, 41)
# Red dot coordinates: (338, 40)
# Red dot coordinates: (341, 40)
# Red dot coordinates: (342, 39)
# Red dot coordinates: (348, 39)
# Red dot coordinates: (349, 38)
# Red dot coordinates: (378, 38)
# Red dot coordinates: (379, 37)
# Red dot coordinates: (387, 37)
# Red dot coordinates: (388, 36)
# Red dot coordinates: (404, 36)
# Red dot coordinates: (405, 37)
# Red dot coordinates: (406, 37)
# Red dot coordinates: (407, 38)
# Red dot coordinates: (408, 38)
# Red dot coordinates: (409, 39)
# Red dot coordinates: (410, 39)
# Red dot coordinates: (412, 41)
# Red dot coordinates: (413, 41)
# Red dot coordinates: (414, 42)
# Red dot coordinates: (415, 42)
# Red dot coordinates: (416, 43)
# Red dot coordinates: (417, 43)
# Red dot coordinates: (418, 44)
# Red dot coordinates: (419, 44)
# Red dot coordinates: (420, 45)
# Red dot coordinates: (422, 45)
# Red dot coordinates: (423, 46)
# Red dot coordinates: (424, 46)
# Red dot coordinates: (425, 47)
# Red dot coordinates: (426, 47)
# Red dot coordinates: (427, 48)
# Red dot coordinates: (429, 48)
# Red dot coordinates: (430, 49)
# Red dot coordinates: (431, 49)
# Red dot coordinates: (432, 50)
# Red dot coordinates: (433, 50)
# Red dot coordinates: (437, 54)
# Red dot coordinates: (437, 56)
# Red dot coordinates: (438, 57)
# Red dot coordinates: (438, 64)
# Red dot coordinates: (439, 65)
# Red dot coordinates: (439, 74)
# Red dot coordinates: (440, 75)
# Red dot coordinates: (440, 80)
# Red dot coordinates: (441, 81)
# Red dot coordinates: (441, 93)
# Red dot coordinates: (442, 94)
# Red dot coordinates: (442, 95)
# Red dot coordinates: (443, 96)
# Red dot coordinates: (443, 100)
# Red dot coordinates: (444, 101)
# Red dot coordinates: (444, 103)
# Red dot coordinates: (445, 104)
# Red dot coordinates: (445, 105)
# Red dot coordinates: (446, 105)
# Red dot coordinates: (447, 106)
# Red dot coordinates: (456, 106)
# Red dot coordinates: (457, 105)
# Red dot coordinates: (462, 105)
# Red dot coordinates: (465, 102)
# Red dot coordinates: (466, 102)
# Red dot coordinates: (467, 101)
# Red dot coordinates: (468, 101)
# Red dot coordinates: (469, 100)
# Red dot coordinates: (471, 100)
# Red dot coordinates: (472, 99)
# Red dot coordinates: (473, 99)
# Red dot coordinates: (474, 98)
# Red dot coordinates: (475, 98)
# Red dot coordinates: (478, 95)
# Red dot coordinates: (480, 95)
# Red dot coordinates: (481, 94)
# Red dot coordinates: (482, 94)
# Red dot coordinates: (483, 93)
# Red dot coordinates: (485, 93)
# Red dot coordinates: (486, 92)
# Red dot coordinates: (487, 92)
# Red dot coordinates: (488, 91)
# Red dot coordinates: (489, 91)
# Red dot coordinates: (490, 90)
# Red dot coordinates: (492, 90)
# Red dot coordinates: (493, 89)
# Red dot coordinates: (497, 89)
# Red dot coordinates: (498, 88)
# Red dot coordinates: (500, 88)
# Red dot coordinates: (501, 87)
# Red dot coordinates: (516, 87)
# Red dot coordinates: (517, 86)
# Red dot coordinates: (526, 86)
# Red dot coordinates: (527, 85)
# Red dot coordinates: (535, 85)
# Red dot coordinates: (536, 84)
# Red dot coordinates: (544, 84)
# Red dot coordinates: (545, 83)
# Red dot coordinates: (550, 83)
# Red dot coordinates: (551, 82)
# Red dot coordinates: (554, 82)
# Red dot coordinates: (555, 81)
# Red dot coordinates: (557, 81)
# Red dot coordinates: (558, 80)
# Red dot coordinates: (561, 80)
# Red dot coordinates: (562, 79)
# Red dot coordinates: (565, 79)
# Red dot coordinates: (566, 78)
# Red dot coordinates: (568, 78)
# Red dot coordinates: (569, 77)
# Red dot coordinates: (571, 77)
# Red dot coordinates: (572, 76)
# Red dot coordinates: (574, 76)
# Red dot coordinates: (575, 75)
# Red dot coordinates: (580, 75)
# Red dot coordinates: (582, 77)
# Red dot coordinates: (583, 77)
# Red dot coordinates: (584, 78)
# Red dot coordinates: (587, 78)
# Red dot coordinates: (588, 79)
# Red dot coordinates: (589, 79)
# Red dot coordinates: (591, 81)
# Red dot coordinates: (592, 81)
# Red dot coordinates: (594, 83)
# Red dot coordinates: (594, 84)
# Red dot coordinates: (593, 85)
# Red dot coordinates: (594, 86)
# Red dot coordinates: (594, 103)
# Red dot coordinates: (595, 104)
# Red dot coordinates: (595, 112)
# Red dot coordinates: (596, 113)
# Red dot coordinates: (596, 124)
# Red dot coordinates: (597, 125)
# Red dot coordinates: (597, 133)
# Red dot coordinates: (601, 137)
# Red dot coordinates: (604, 137)
# Red dot coordinates: (605, 138)
# Red dot coordinates: (610, 138)
# Red dot coordinates: (611, 137)
# Red dot coordinates: (613, 137)
# Red dot coordinates: (614, 138)
# Red dot coordinates: (625, 138)
# Red dot coordinates: (626, 139)
# Red dot coordinates: (629, 139)
# Red dot coordinates: (630, 140)
# Red dot coordinates: (638, 140)
# Red dot coordinates: (639, 139)
# Red dot coordinates: (640, 139)
# Red dot coordinates: (642, 137)
# Red dot coordinates: (642, 136)
# Red dot coordinates: (643, 135)
# Red dot coordinates: (643, 131)
# Red dot coordinates: (642, 130)
# Red dot coordinates: (642, 121)
# Red dot coordinates: (644, 119)
# Red dot coordinates: (646, 119)
# Red dot coordinates: (647, 118)
# Red dot coordinates: (666, 118)
# Red dot coordinates: (667, 117)
# Red dot coordinates: (668, 117)
# Red dot coordinates: (674, 111)
# Red dot coordinates: (675, 111)
# Red dot coordinates: (679, 107)
# Red dot coordinates: (679, 106)
# Red dot coordinates: (682, 103)
# Red dot coordinates: (682, 102)
# Red dot coordinates: (683, 101)
# Red dot coordinates: (683, 99)
# Red dot coordinates: (684, 98)
# Red dot coordinates: (684, 96)
# Red dot coordinates: (685, 95)
# Red dot coordinates: (685, 92)
# Red dot coordinates: (683, 90)
# Red dot coordinates: (683, 86)
# Red dot coordinates: (682, 85)
# Red dot coordinates: (682, 80)
# Red dot coordinates: (681, 79)
# Red dot coordinates: (681, 75)
# Red dot coordinates: (680, 74)
# Red dot coordinates: (680, 69)
# Red dot coordinates: (679, 68)
# Red dot coordinates: (679, 62)
# Red dot coordinates: (678, 61)
# Red dot coordinates: (678, 57)
# Red dot coordinates: (677, 56)
# Red dot coordinates: (677, 51)
# Red dot coordinates: (676, 50)
# Red dot coordinates: (676, 49)
# Red dot coordinates: (675, 48)
# Red dot coordinates: (677, 46)
# Red dot coordinates: (680, 46)
# Red dot coordinates: (681, 45)
# Red dot coordinates: (683, 45)
# Red dot coordinates: (685, 43)
# Red dot coordinates: (686, 43)
# Red dot coordinates: (688, 41)
# Red dot coordinates: (689, 41)
# Red dot coordinates: (693, 37)
# Red dot coordinates: (694, 37)
# Red dot coordinates: (696, 35)
# Red dot coordinates: (697, 35)
# Red dot coordinates: (699, 33)
# Red dot coordinates: (700, 33)
# Red dot coordinates: (701, 32)
# Red dot coordinates: (702, 32)
# Red dot coordinates: (703, 31)
# Red dot coordinates: (705, 31)
# Red dot coordinates: (706, 30)
# Red dot coordinates: (707, 30)
# Red dot coordinates: (708, 29)
# Red dot coordinates: (709, 29)
# Red dot coordinates: (710, 28)
# Red dot coordinates: (712, 28)
# Red dot coordinates: (713, 27)
# Red dot coordinates: (714, 27)
# Red dot coordinates: (715, 26)
# Red dot coordinates: (717, 26)
# Red dot coordinates: (718, 25)
# Red dot coordinates: (719, 25)
# Red dot coordinates: (720, 24)
# Red dot coordinates: (721, 24)
# Red dot coordinates: (723, 22)
# Red dot coordinates: (724, 22)
# Red dot coordinates: (726, 20)
# Red dot coordinates: (727, 20)
# Red dot coordinates: (728, 19)
# Red dot coordinates: (729, 19)
# Red dot coordinates: (731, 17)
# Red dot coordinates: (732, 17)
# Red dot coordinates: (733, 16)
# Red dot coordinates: (734, 16)
# Red dot coordinates: (735, 15)
# Red dot coordinates: (737, 15)
# Red dot coordinates: (738, 14)
# Red dot coordinates: (738, 9)
# Red dot coordinates: (737, 8)
# Red dot coordinates: (736, 8)
# Red dot coordinates: (735, 7)

# %%
# Reverse the y-coordinates
y_coords = max(y_coords) - y_coords

# MLP Model
model = Sequential()
model.add(Dense(32, input_dim=1, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Split the coordinates into training and test data
x_train, x_test, y_train, y_test = train_test_split(x_coords, y_coords, test_size=0.25, random_state=42)

# Convert the 1D arrays to 2D arrays for compatibility with the model
x_train = np.reshape(x_train, (-1, 1))
y_train = np.reshape(y_train, (-1, 1))
x_test = np.reshape(x_test, (-1, 1))
y_test = np.reshape(y_test, (-1, 1))

# %%
# Train the model
history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=0)

# %%
# Make predictions
predictions = model.predict(x_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# Sort the test data points based on x_test
sorted_indices = np.argsort(x_test.flatten())
x_test_sorted = x_test[sorted_indices]
y_test_sorted = y_test[sorted_indices]
predictions_sorted = predictions[sorted_indices]

# Evaluate the model
mse = np.mean((predictions - y_test) ** 2)
print("Mean Squared Error (MSE):", mse)

# Plot the results
plt.figure(figsize=(8, 6))
plt.scatter(x_test_sorted, y_test_sorted, color='blue', label='Actual')
plt.plot(x_test_sorted, predictions_sorted, color='red', label='Predicted')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Approximation of Red Line with MLP')
plt.legend()
plt.show()
# Out:
# Mean Squared Error (MSE): 3402.8749584360944
